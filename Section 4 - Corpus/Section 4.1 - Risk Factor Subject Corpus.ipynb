# %% [markdown]
# # Section 4.1 Risk Factors Subject Corpus
#
# In this section we are going to build up a corpus based on the risk factors subject.

# %%
import pandas as pd
import numpy as np
import requests
import os
import re
import html
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 4.1.1 Download the .txt files from SEC website
#
# In the section 1, we have generate the url for downloading the financial report in HTML format. Now we use it to download more files (3000 files) to build up our corpus.

# %%
_22FY10KFile_df = pd.read_csv("../Section 1 - Datasets Downloads and Preparation/22FY10KFile.csv")

# %%
# this function is to download the .txt file from the corresponding url.
def download_file(url, downloadPath, headerEmail):
    # request the url
    headers = {"User-Agent": headerEmail}
    response = requests.get(url, headers = headers)
    
    if response.status_code == 200:
        fileContent = response.text
        with open(downloadPath, 'w', encoding='utf-8') as file:
            file.write(fileContent)
        print("Download successifully.")
    else:
        print("Fail to download.")

# %%
headerEmail = "yuchaoba@usc.edu"
for i in range(0,3000):
    url = _22FY10KFile_df["filing_url"].iloc[i]
    folderPath = "Downloaded Corpus/"
    fileName = str(_22FY10KFile_df["adsh"].iloc[i]) + ".txt"
    downloadPath = folderPath + fileName
    download_file(url, downloadPath, headerEmail)

# %% [markdown]
# ## 4.1.2 Extract the risk factors
# ### 1.  Extract the risk factors raw text
#
# The whole files are too big to process in one time, so we divide them into 3 parts and extract the subjects from them seperately. The steps are quite similar to the Section 2.
#
# 1. Part 1:

# %%
folderPath = "Downloaded Corpus/"
fileName_lst = os.listdir(folderPath)
filePair_dict = {} # filePair stores the file name and the corresponding file text.
for fileName in fileName_lst[:1000]:  
    # encode each document
    filePath = str(folderPath) + str(fileName)    
    with open(filePath, 'r', encoding='utf-8') as file:
        fileText = file.read()
    filePair_dict[fileName] = fileText
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 for fileName in fileName_lst[:1000]:
#       5     # encode each document
#       6     filePath = str(folderPath) + str(fileName)
# ----> 7     with open(filePath, 'r', encoding='utf-8') as file:
#       8         fileText = file.read()
#       9     filePair_dict[fileName] = fileText
#
# KeyboardInterrupt:

# %%
def remove_tags(text):
    # replace the tag included by <> to a \ 
    pattern1 = r'<[^>]*>'
    cleanText = re.sub(pattern1, "|", text)
    
    # replace the multiple continued \ to a single \
    cleanText = re.sub(r'\s*\|+\s*', '|', cleanText)
    cleanText = re.sub(r'\|+', '|', cleanText)
    
    # replace the unicode
    cleanText = html.unescape(cleanText)
    
    # remove the line break
    cleanText = cleanText.replace('\n', '')
    # remove the pure numbers text between \
    cleanText = re.sub(r'\|(\d+)\|', '|', cleanText)
    # remove the unrecognized string
    cleanText = re.sub(r'|\xa0\|', '', cleanText)
    cleanText = re.sub(r'|\xa0|', '', cleanText)
    return cleanText

# %%
def separate_main_body(text):
    lastContentInTC_lst = [">form 10-k summary<", ">item 16. form 10-k summary<", r">exhibits, financial statement schedules<", 
                           r">exhibits and financial statement schedules<", r"exhibits and financial statement schedules <",
                           ">exhibits<"]
    start_idx = -1
    for content in lastContentInTC_lst:
        if content in text.lower():
            start_idx = text.lower().find(content)
            break
            
    if start_idx == -1:
        return False
    
    mainBody = text[start_idx:]
    mainBody = html.unescape(mainBody)
    return mainBody

# %%
def extract_risk_factors(mainBody, fileName):
    # match the risk factor
    keywordMatch = re.findall(r">item 1a.\s+risk factors\.?\<", mainBody.lower())
    
    # if fail to match the pattern, the pattern might be segmented be some html tags, so re-match
    if not keywordMatch:
        keyword = seperated_keyword_rematch(mainBody)
        
    # if match the pattern successfully, just keep the keyword of risk factor
    else:
        keyword = keywordMatch[0]
    
    # check if match successfully
    if not keyword:
        return False
    keywordCheck_lst = ["item", r"item 1a\.?", "risk", "factors", "risk factors"]
    if keyword in keywordCheck_lst:
        print("Warning: It is better to check whether the extraction is correct manually for file", {fileName})
    
    # match the next section of the risk factor
    nextSectionPattern_lst = [r">item 1b.\s+unresolved staff comments\.?\<", r">item 2.\s+description of property\.?\<"]
    for pattern in nextSectionPattern_lst:
        nextSectionMatch = re.findall(pattern, mainBody.lower())
        
        # if fail to match the pattern, the pattern might be segmented be some html tags, so re-match
        if not nextSectionMatch:
            nextSection = seperated_next_section_rematch(mainBody, pattern)
            # if re-match successfully, jump out of the loop
            if nextSection:
                break
        
        # if match the pattern successfully, just keep the next section keyword and jump out of the loop
        else:
            nextSection = nextSectionMatch[0]
            break
    
    # check if match successfully
    if not nextSection:
        return False
    
    # if match successfully, extract the risk factor
    start_idx = mainBody.lower().find(keyword) # start index is the position of the keyword occured in the main body
    end_idx = mainBody.lower().find(nextSection) # end index is the position of the next section begin in the main body
    riskFactors = mainBody[start_idx: end_idx]
    return riskFactors

# %%
def seperated_keyword_rematch(mainBody):
    cleanedMainBody = remove_tags(mainBody)
    keywordMatch = re.findall(r"i\|?t\|?e\|?m\|?\s+\|?1\|?a\|?.\|?\s+\|?r\|?i\|?s\|?k\|?\s+\|?f\|?a\|?c\|?t\|?o\|?r\|?s\.?", cleanedMainBody.lower())
    
    # check if re-match the keyword of risk factor successfully
    if not keywordMatch:
        return False
    
    # if re-match successfully, use the longer segmentation as the keyword of the risk factor
    reMatchedKeyword = max(keywordMatch[0].split('|'), key=len)
    return reMatchedKeyword
    
def seperated_next_section_rematch(mainBody, nextSectionPattern):
    # cleanse the main body text
    cleanedMainBody = remove_tags(mainBody)
    
    # edit the pattern 
    edittedPattern = nextSectionPattern.replace(r">", "").replace(r"\s+", " ").replace(r"\.?\<", "")
    edittedPattern = "\|?".join(edittedPattern)
    edittedPattern = r"{}\.?".format(edittedPattern)
    pattern = edittedPattern.replace(" ", "\s?+")
    nextSectionMatch = re.findall(pattern, cleanedMainBody.lower())
    
    # check if re-match the keyword of next section successfully
    if not nextSectionMatch:
        return False
    
    # if re-match successfully, use the longer segmentation as the keyword of the next section 
    reMatchedNextSection = max(nextSectionMatch[0].split('|'), key=len)
    return reMatchedNextSection

# %%
for key, value in filePair_dict.items():
    fileName = key
    fileText = value
    mainBody = separate_main_body(fileText) # separate the original text as the table of content and the main body.
    
    if not mainBody:
        print("The extraction is failed for", {fileName}, "because of the error in seperating main body.")
        continue
    
    riskText = extract_risk_factors(mainBody, fileName) # extract the risk related text
    if not riskText:
        print("The extraction is failed for", {fileName}, "because of the error in extracting risk factors.")
    else:
        riskFilePath = "Corpus Extraction/Part 1/Raw Text/" + fileName
        with open(riskFilePath, 'w', encoding='utf-8') as file:
            file.write(riskText)
# Out:
# The extraction is failed for {'0000002488-23-000047.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0
txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-005271.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-005567.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-005793.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-005851.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-005934.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-006018.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-006304.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-006314.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-006366.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-006580.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-006587.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-006630.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-006895.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-006924.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007036.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007129.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007178.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007252.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007259.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007351.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007472.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007481.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007482.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-007490.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007533.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007614.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007686.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-007726.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007793.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007925.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-007974.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-007977.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-008111.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-008161.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-008173.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-008241.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-008326.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-008518.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-008716.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-008751.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-008765.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-008878.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-008898.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-008914.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009060.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009074.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009080.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009090.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009091.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009106.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009124.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009153.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009183.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009190.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-009208.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009306.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-009381.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009385.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009418.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009465.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009468.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009477.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009516.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009563.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009567.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-009598.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009604.txt'} because of the error in extracting risk factors.

# %% [markdown]
# 3. Part 3:

# %%
folderPath = "Downloaded Corpus/"
fileName_lst = os.listdir(folderPath)
filePair_dict = {} # filePair stores the file name and the corresponding file text.
for fileName in fileName_lst[2000:3000]:  
    # encode each document
    filePath = str(folderPath) + str(fileName)    
    with open(filePath, 'r', encoding='utf-8') as file:
        fileText = file.read()
    filePair_dict[fileName] = fileText

# %%
for key, value in filePair_dict.items():
    fileName = key
    fileText = value
    mainBody = separate_main_body(fileText) # separate the original text as the table of content and the main body.
    
    if not mainBody:
        print("The extraction is failed for", {fileName}, "because of the error in seperating main body.")
        continue
    
    riskText = extract_risk_factors(mainBody, fileName) # extract the risk related text
    if not riskText:
        print("The extraction is failed for", {fileName}, "because of the error in extracting risk factors.")
    else:
        riskFilePath = "Corpus Extraction/Part 3/Raw Text/" + fileName
        with open(riskFilePath, 'w', encoding='utf-8') as file:
            file.write(riskText)
# Out:
# The extraction is failed for {'0001493152-23-009605.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009609.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-009730.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009799.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009812.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009824.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009840.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-009844.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009866.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-009872.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009881.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009883.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-009928.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-009940.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010023.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010055.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010074.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010092.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010103.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010104.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010108.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010110.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010137.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010142.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010152.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010178.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010215.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010221.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010223.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010237.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010249.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010251.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010256.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010259.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010263.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010279.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010282.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010283.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010284.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010285.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010294.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010295.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010328.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010332.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010336.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010351.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010356.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010357.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010358.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010371.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010382.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010383.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010384.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010392.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001493152-23-010393.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010400.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010431.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001493152-23-010441.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001494650-23-000020.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001506293-23-000023.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001509589-23-000017.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001513162-22-000114.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001516551-23-000038.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001520006-23-000056.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001520138-22-000131.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001520138-22-000437.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001521332-23-000013.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001524931-23-000007.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001528129-23-000048.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001528396-22-000106.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001529274-23-000037.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001530979-23-000038.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001534992-23-000015.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001535527-22-000006.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001538210-23-000007.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001539497-22-000793.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001539497-22-001510.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001546417-23-000009.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001548123-23-000051.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001548123-23-000062.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001549346-23-000011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001552781-22-000463.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001553350-22-000745.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001553350-22-000785.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001553350-22-000798.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001554795-22-000255.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001554795-23-000091.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001554795-23-000093.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001554795-23-000097.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001554795-23-000098.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001554855-23-000184.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-22-003921.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-004330.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-004512.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-22-004595.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-004753.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-005217.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-005527.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-006372.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-009390.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-22-010392.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-010443.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-013680.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-013940.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-013954.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-22-014362.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-014404.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-014600.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-22-014652.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-001114.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-001378.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-23-001574.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-23-001652.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-23-001895.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-001902.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-001913.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-001916.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-001969.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002068.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002102.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002110.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002238.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002252.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002328.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-23-002344.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-23-002371.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002419.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001558370-23-002558.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002560.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002572.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002586.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002588.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002605.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002684.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-002693.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001558370-23-
23-000003.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001674335-23-000039.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001677703-23-000011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001679082-22-000071.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001679363-23-000011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001682852-23-000011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002280.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002406.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002484.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-22-002671.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002677.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002694.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-22-002703.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002719.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002722.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002725.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002731.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-22-002736.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-002738.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-004120.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-004566.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-004603.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-004633.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-004668.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-004681.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-22-004704.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-004940.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-005073.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-22-005490.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-22-006633.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-000938.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-001344.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-001509.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-23-001645.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-001674.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-001678.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-001703.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-001765.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-23-001850.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-001993.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-23-002005.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-002024.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001683168-23-002076.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-002086.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001683168-23-002090.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001688568-22-000027.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001689923-23-000012.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001692819-23-000005.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001698991-23-000010.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001708055-23-000003.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001710495-22-000004.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001720990-23-000020.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001731122-22-000823.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001731122-23-000490.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001731122-23-000547.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001737953-22-000010.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001739445-23-000018.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001751008-23-000006.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001753391-22-000019.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001753926-23-000115.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001753926-23-000342.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001753926-23-000347.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001753926-23-000352.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001757898-22-000011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001760965-23-000007.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001764046-23-000012.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001779372-23-000006.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001779474-23-000023.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001781629-23-000004.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001784031-23-000007.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001784031-23-000008.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001789940-23-000011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001792044-23-000008.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001795250-22-000013.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001798270-23-000007.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001798749-23-000015.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001800227-23-000009.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001801661-23-000005.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001806201-23-000033.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001810019-23-000034.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001811884-23-000004.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001817358-22-000039.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001818093-23-000006.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001818382-23-000016.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001818644-23-000003.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001819574-22-000049.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001819881-23-000007.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001819974-23-000011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001821825-23-000003.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001828108-23-000020.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-22-007895.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-22-008021.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-22-014453.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-22-016532.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-001055.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-001461.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-001524.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-001661.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-001983.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002008.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002011.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002018.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002099.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002201.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002255.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-002347.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-002407.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002409.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-002428.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002435.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-002448.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002490.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-002497.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002504.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002505.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-002511.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001829126-23-002515.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001829126-23-002516.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001835591-23-000022.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001835632-22-000016.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001836875-23-000066.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001840856-23-000019.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001842952-23-000041.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001847903-23-000063.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001851734-22-000194.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001851734-22-000349.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001851734-22-000574.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001856525-22-000013.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001859644-23-000005.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001860782-23-000038.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001866175-23-000010.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001874178-23-000009.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001903596-22-000199.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001903596-23-000047.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001903596-23-000255.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001906324-23-000014.txt'} because of the error in extracting risk factors.
# The extraction is failed for {'0001935979-23-000009.txt'} because of the error in seperating main body.
# The extraction is failed for {'0001937653-23-000011.txt'} because of the error in extracting risk factors.

# %% [markdown]
# ## 4.1.3. Extract the risk factors subject
#
# Also, we need to extract the risk factors subject for these 3 parts.
#
# 1. Part 1:

# %%
from bs4 import BeautifulSoup

def extract_subjects(riskFactors, subjectFormat):
    soup = BeautifulSoup(riskFactors, 'html.parser')
    subject_lst = []
    for span in soup.find_all('span'):
        style = span.get('style')
        if style and subjectFormat in style:
            subject_lst.append(span.get_text())
    return subject_lst

# %%
rawTextFolderPath = "Corpus Extraction/Part 1/Raw Text/"
rawTextFileName_lst = os.listdir(rawTextFolderPath)
rawTextFilePair_dict = {} # filePair stores the file name and the corresponding file text.
for fileName in rawTextFileName_lst:  
    # encode each document
    filePath = str(rawTextFolderPath) + str(fileName)    
    with open(filePath, 'r', encoding='utf-8') as file:
        rawText = file.read()
    rawTextFilePair_dict[fileName] = rawText

# %%
subjectFormat_lst = ["font-weight:700", "font-weight:bold"]
for key, value in rawTextFilePair_dict.items():
    fileName = key
    rawText = value
    
    i = 0
    subject_lst = []
    
    while not subject_lst:
        subjectFormat = subjectFormat_lst[i]
        subject_lst = extract_subjects(rawText, subjectFormat)
        i += 1
        if i >= len(subjectFormat_lst):
            break
        
    if not subject_lst:
        print("The subject fail to extract for", {fileName})
    else:
        subjectFolder = "Corpus Extraction/Part 1/Subject/"
        subjectFilePath = subjectFolder + str(fileName)
        with open(subjectFilePath, 'w', encoding='utf-8') as file:
            for item in subject_lst:
                file.write(item + '\n')
# Out:
# The subject fail to extract for {'0000107140-22-000022.txt'}
# The subject fail to extract for {'0000355019-22-000042.txt'}
# The subject fail to extract for {'0000874015-23-000105.txt'}
# The subject fail to extract for {'0000898432-23-000193.txt'}
# The subject fail to extract for {'0000930413-23-001072.txt'}
# The subject fail to extract for {'0001017386-22-000150.txt'}
# The subject fail to extract for {'0001017386-23-000093.txt'}
# The subject fail to extract for {'0001058090-23-000010.txt'}
# The subject fail to extract for {'0001062993-22-015574.txt'}
# The subject fail to extract for {'0001062993-23-007669.txt'}
# The subject fail to extract for {'0001062993-23-008012.txt'}
# The subject fail to extract for {'0001065949-22-000047.txt'}
# The subject fail to extract for {'0001065949-23-000017.txt'}
# The subject fail to extract for {'0001079973-22-000422.txt'}
# The subject fail to extract for {'0001079973-22-000424.txt'}
# The subject fail to extract for {'0001079973-23-000353.txt'}
# The subject fail to extract for {'0001079973-23-000382.txt'}
# The subject fail to extract for {'0001096906-22-000873.txt'}
# The subject fail to extract for {'0001096906-22-000930.txt'}
# The subject fail to extract for {'0001096906-22-001512.txt'}
# The subject fail to extract for {'0001096906-22-001519.txt'}
# The subject fail to extract for {'0001096906-23-000237.txt'}
# The subject fail to extract for {'0001096906-23-000607.txt'}
# The subject fail to extract for {'0001096906-23-000648.txt'}
# The subject fail to extract for {'0001096906-23-000683.txt'}
# The subject fail to extract for {'0001104659-22-042727.txt'}
# The subject fail to extract for {'0001104659-23-037770.txt'}
# The subject fail to extract for {'0001140361-22-011225.txt'}
# The subject fail to extract for {'0001140361-22-013445.txt'}
# The subject fail to extract for {'0001140361-22-013998.txt'}
# The subject fail to extract for {'0001140361-22-014279.txt'}
# The subject fail to extract for {'0001140361-22-014703.txt'}
# The subject fail to extract for {'0001140361-22-015616.txt'}
# The subject fail to extract for {'0001140361-22-034827.txt'}
# The subject fail to extract for {'0001140361-23-007348.txt'}
# The subject fail to extract for {'0001140361-23-012844.txt'}
# The subject fail to extract for {'0001140361-23-014279.txt'}
# The subject fail to extract for {'0001140361-23-014526.txt'}
# The subject fail to extract for {'0001140361-23-014608.txt'}
# The subject fail to extract for {'0001140361-23-014868.txt'}
# The subject fail to extract for {'0001140361-23-015464.txt'}
# The subject fail to extract for {'0001161697-22-000222.txt'}
# The subject fail to extract for {'0001161697-23-000158.txt'}
# The subject fail to extract for {'0001171843-22-002601.txt'}
# The subject fail to extract for {'0001171843-23-000476.txt'}
# The subject fail to extract for {'0001171843-23-001691.txt'}
# The subject fail to extract for {'0001171843-23-001729.txt'}
# The subject fail to extract for {'0001185185-22-000451.txt'}
# The subject fail to extract for {'0001185185-22-000456.txt'}
# The subject fail to extract for {'0001185185-22-000457.txt'}
# The subject fail to extract for {'0001185185-22-000768.txt'}
# The subject fail to extract for {'0001185185-22-000822.txt'}
# The subject fail to extract for {'0001185185-23-000161.txt'}
# The subject fail to extract for {'0001185185-23-000244.txt'}
# The subject fail to extract for {'0001185185-23-000295.txt'}
# The subject fail to extract for {'0001185185-23-000299.txt'}
# The subject fail to extract for {'0001185185-23-000305.txt'}
# The subject fail to extract for {'0001193125-22-087521.txt'}
# The subject fail to extract for {'0001193125-22-092124.txt'}
# The subject fail to extract for {'0001193125-22-092205.txt'}
# The subject fail to extract for {'0001193125-22-092373.txt'}
# The subject fail to extract for {'0001193125-22-099237.txt'}
# The subject fail to extract for {'0001193125-22-106571.txt'}
# The subject fail to extract for {'0001193125-22-106792.txt'}
# The subject fail to extract for {'0001193125-22-157681.txt'}
# The subject fail to extract for {'0001193125-22-202902.txt'}

# %% [markdown]
# 2. Part 2:

# %%
rawTextFolderPath = "Corpus Extraction/Part 2/Raw Text/"
rawTextFileName_lst = os.listdir(rawTextFolderPath)
rawTextFilePair_dict = {} # filePair stores the file name and the corresponding file text.
for fileName in rawTextFileName_lst:  
    # encode each document
    filePath = str(rawTextFolderPath) + str(fileName)    
    with open(filePath, 'r', encoding='utf-8') as file:
        rawText = file.read()
    rawTextFilePair_dict[fileName] = rawText

# %%
subjectFormat_lst = ["font-weight:700", "font-weight:bold"]
for key, value in rawTextFilePair_dict.items():
    fileName = key
    rawText = value
    
    i = 0
    subject_lst = []
    
    while not subject_lst:
        subjectFormat = subjectFormat_lst[i]
        subject_lst = extract_subjects(rawText, subjectFormat)
        i += 1
        if i >= len(subjectFormat_lst):
            break
        
    if not subject_lst:
        print("The subject fail to extract for", {fileName})
    else:
        subjectFolder = "Corpus Extraction/Part 2/Subject/"
        subjectFilePath = subjectFolder + str(fileName)
        with open(subjectFilePath, 'w', encoding='utf-8') as file:
            for item in subject_lst:
                file.write(item + '\n')
# Out:
# The subject fail to extract for {'0001193311-23-000005.txt'}
# The subject fail to extract for {'0001213900-22-016996.txt'}
# The subject fail to extract for {'0001213900-22-017017.txt'}
# The subject fail to extract for {'0001213900-22-017095.txt'}
# The subject fail to extract for {'0001213900-22-017118.txt'}
# The subject fail to extract for {'0001213900-22-017159.txt'}
# The subject fail to extract for {'0001213900-22-017248.txt'}
# The subject fail to extract for {'0001213900-22-018211.txt'}
# The subject fail to extract for {'0001213900-22-018523.txt'}
# The subject fail to extract for {'0001213900-22-018778.txt'}
# The subject fail to extract for {'0001213900-22-019078.txt'}
# The subject fail to extract for {'0001213900-22-019210.txt'}
# The subject fail to extract for {'0001213900-22-019367.txt'}
# The subject fail to extract for {'0001213900-22-019421.txt'}
# The subject fail to extract for {'0001213900-22-019444.txt'}
# The subject fail to extract for {'0001213900-22-019472.txt'}
# The subject fail to extract for {'0001213900-22-019498.txt'}
# The subject fail to extract for {'0001213900-22-019609.txt'}
# The subject fail to extract for {'0001213900-22-019857.txt'}
# The subject fail to extract for {'0001213900-22-019878.txt'}
# The subject fail to extract for {'0001213900-22-019928.txt'}
# The subject fail to extract for {'0001213900-22-020040.txt'}
# The subject fail to extract for {'0001213900-22-020108.txt'}
# The subject fail to extract for {'0001213900-22-020111.txt'}
# The subject fail to extract for {'0001213900-22-020136.txt'}
# The subject fail to extract for {'0001213900-22-020143.txt'}
# The subject fail to extract for {'0001213900-22-020144.txt'}
# The subject fail to extract for {'0001213900-22-020167.txt'}
# The subject fail to extract for {'0001213900-22-020195.txt'}
# The subject fail to extract for {'0001213900-22-020959.txt'}
# The subject fail to extract for {'0001213900-22-025339.txt'}
# The subject fail to extract for {'0001213900-22-027311.txt'}
# The subject fail to extract for {'0001213900-22-033681.txt'}
# The subject fail to extract for {'0001213900-22-035190.txt'}
# The subject fail to extract for {'0001213900-22-035892.txt'}
# The subject fail to extract for {'0001213900-22-035983.txt'}
# The subject fail to extract for {'0001213900-22-036284.txt'}
# The subject fail to extract for {'0001213900-22-039607.txt'}
# The subject fail to extract for {'0001213900-22-047017.txt'}
# The subject fail to extract for {'0001213900-22-057677.txt'}
# The subject fail to extract for {'0001213900-22-059573.txt'}
# The subject fail to extract for {'0001213900-22-059740.txt'}
# The subject fail to extract for {'0001213900-23-005085.txt'}
# The subject fail to extract for {'0001213900-23-011520.txt'}
# The subject fail to extract for {'0001213900-23-012940.txt'}
# The subject fail to extract for {'0001213900-23-014314.txt'}
# The subject fail to extract for {'0001213900-23-014856.txt'}
# The subject fail to extract for {'0001213900-23-016875.txt'}
# The subject fail to extract for {'0001213900-23-017591.txt'}
# The subject fail to extract for {'0001213900-23-017837.txt'}
# The subject fail to extract for {'0001213900-23-018373.txt'}
# The subject fail to extract for {'0001213900-23-018635.txt'}
# The subject fail to extract for {'0001213900-23-019202.txt'}
# The subject fail to extract for {'0001213900-23-019976.txt'}
# The subject fail to extract for {'0001213900-23-020383.txt'}
# The subject fail to extract for {'0001213900-23-021418.txt'}
# The subject fail to extract for {'0001213900-23-021454.txt'}
# The subject fail to extract for {'0001213900-23-021526.txt'}
# The subject fail to extract for {'0001213900-23-021852.txt'}
# The subject fail to extract for {'0001213900-23-022071.txt'}
# The subject fail to extract for {'0001213900-23-022590.txt'}
# The subject fail to extract for {'0001213900-23-022628.txt'}
# The subject fail to extract for {'0001213900-23-022793.txt'}
# The subject fail to extract for {'0001213900-23-022813.txt'}
# The subject fail to extract for {'0001213900-23-022828.txt'}
# The subject fail to extract for {'0001213900-23-023197.txt'}
# The subject fail to extract for {'0001213900-23-023500.txt'}
# The subject fail to extract for {'0001213900-23-023646.txt'}
# The subject fail to extract for {'0001213900-23-024075.txt'}
# The subject fail to extract for {'0001213900-23-024079.txt'}
# The subject fail to extract for {'0001213900-23-024115.txt'}
# The subject fail to extract for {'0001213900-23-024118.txt'}
# The subject fail to extract for {'0001213900-23-024122.txt'}
# The subject fail to extract for {'0001213900-23-024161.txt'}
# The subject fail to extract for {'0001213900-23-024205.txt'}
# The subject fail to extract for {'0001213900-23-024260.txt'}
# The subject fail to extract for {'0001213900-23-024310.txt'}
# The subject fail to extract for {'0001213900-23-024571.txt'}
# The subject fail to extract for {'0001213900-23-024626.txt'}
# The subject fail to extract for {'0001213900-23-024627.txt'}
# The subject fail to extract for {'0001213900-23-024677.txt'}
# The subject fail to extract for {'0001213900-23-024687.txt'}
# The subject fail to extract for {'0001213900-23-024691.txt'}
# The subject fail to extract for {'0001213900-23-024710.txt'}
# The subject fail to extract for {'0001213900-23-024716.txt'}
# The subject fail to extract for {'0001213900-23-024727.txt'}
# The subject fail to extract for {'0001213900-23-024748.txt'}
# The subject fail to extract for {'0001213900-23-024750.txt'}
# The subject fail to extract for {'0001213900-23-024776.txt'}
# The subject fail to extract for {'0001213900-23-024810.txt'}
# The subject fail to extract for {'0001213900-23-024827.txt'}
# The subject fail to extract for {'0001213900-23-024843.txt'}
# The subject fail to extract for {'0001213900-23-024901.txt'}
# The subject fail to extract for {'0001213900-23-024918.txt'}
# The subject fail to extract for {'0001213900-23-024920.txt'}
# The subject fail to extract for {'0001213900-23-024935.txt'}
# The subject fail to extract for {'0001213900-23-025083.txt'}
# The subject fail to extract for {'0001213900-23-025143.txt'}
# The subject fail to extract for {'0001213900-23-025215.txt'}
# The subject fail to extract for {'0001213900-23-025396.txt'}
# The subject fail to extract for {'0001213900-23-025417.txt'}
# The subject fail to extract for {'0001213900-23-025437.txt'}
# The subject fail to extract for {'0001213900-23-025445.txt'}
# The subject fail to extract for {'0001213900-23-025449.txt'}
# The subject fail to extract for {'0001213900-23-025455.txt'}
# The subject fail to extract for {'0001213900-23-025466.txt'}
# The subject fail to extract for {'0001213900-23-025478.txt'}
# The subject fail to extract for {'0001213900-23-025486.txt'}
# The subject fail to extract for {'0001213900-23-025498.txt'}
# The subject fail to extract for {'0001213900-23-025507.txt'}
# The subject fail to extract for {'0001213900-23-025527.txt'}
# The subject fail to extract for {'0001213900-23-025543.txt'}
# The subject fail to extract for {'0001213900-23-025554.txt'}
# The subject fail to extract for {'0001213900-23-025556.txt'}
# The subject fail to extract for {'0001213900-23-025584.txt'}
# The subject fail to extract for {'0001213900-23-025597.txt'}
# The subject fail to extract for {'0001213900-23-025611.txt'}
# The subject fail to extract for {'0001213900-23-025613.txt'}
# The subject fail to extract for {'0001213900-23-025634.txt'}
# The subject fail to extract for {'0001214659-22-004941.txt'}
# The subject fail to extract for {'0001214659-22-005395.txt'}
# The subject fail to extract for {'0001214659-23-004512.txt'}
# The subject fail to extract for {'0001262463-22-000125.txt'}
# The subject fail to extract for {'0001264931-22-000154.txt'}
# The subject fail to extract for {'0001387131-22-004799.txt'}
# The subject fail to extract for {'0001397702-23-000012.txt'}
# The subject fail to extract for {'0001410578-22-000824.txt'}
# The subject fail to extract for {'0001410578-22-000941.txt'}
# The subject fail to extract for {'0001410578-22-000947.txt'}
# The subject fail to extract for {'0001410578-22-000970.txt'}
# The subject fail to extract for {'0001410578-22-001930.txt'}
# The subject fail to extract for {'0001410578-23-000055.txt'}
# The subject fail to extract for {'0001410578-23-000136.txt'}
# The subject fail to extract for {'0001410578-23-000153.txt'}
# The subject fail to extract for {'0001410578-23-000470.txt'}
# The subject fail to extract for {'0001410578-23-000571.txt'}
# The subject fail to extract for {'0001437749-22-007905.txt'}
# The subject fail to extract for {'0001437749-22-008152.txt'}
# The subject fail to extract for {'0001437749-22-008182.txt'}
# The subject fail to extract for {'0001437749-22-009005.txt'}
# The subject fail to extract for {'0001437749-22-009050.txt'}
# The subject fail to extract for {'0001437749-22-015762.txt'}
# The subject fail to extract for {'0001437749-22-022143.txt'}
# The subject fail to extract for {'0001437749-22-022334.txt'}
# The subject fail to extract for {'0001437749-22-023256.txt'}
# The subject fail to extract for {'0001437749-23-003778.txt'}
# The subject fail to extract for {'0001437749-23-003782.txt'}
# The subject fail to extract for {'0001437749-23-003931.txt'}
# The subject fail to extract for {'0001437749-23-004329.txt'}
# The subject fail to extract for {'0001437749-23-004331.txt'}
# The subject fail to extract for {'0001437749-23-004332.txt'}
# The subject fail to extract for {'0001437749-23-004334.txt'}
# The subject fail to extract for {'0001437749-23-004361.txt'}
# The subject fail to extract for {'0001437749-23-004454.txt'}
# The subject fail to extract for {'0001437749-23-004477.txt'}
# The subject fail to extract for {'0001437749-23-004508.txt'}
# The subject fail to extract for {'0001437749-23-004540.txt'}
# The subject fail to extract for {'0001437749-23-004908.txt'}
# The subject fail to extract for {'0001437749-23-004928.txt'}
# The subject fail to extract for {'0001437749-23-005056.txt'}
# The subject fail to extract for {'0001437749-23-005106.txt'}
# The subject fail to extract for {'0001437749-23-005218.txt'}
# The subject fail to extract for {'0001437749-23-005233.txt'}
# The subject fail to extract for {'0001437749-23-005241.txt'}
# The subject fail to extract for {'0001437749-23-005378.txt'}
# The subject fail to extract for {'0001437749-23-006086.txt'}
# The subject fail to extract for {'0001437749-23-006169.txt'}
# The subject fail to extract for {'0001437749-23-006264.txt'}
# The subject fail to extract for {'0001437749-23-006585.txt'}
# The subject fail to extract for {'0001437749-23-006587.txt'}
# The subject fail to extract for {'0001437749-23-006745.txt'}
# The subject fail to extract for {'0001437749-23-006845.txt'}
# The subject fail to extract for {'0001437749-23-006914.txt'}
# The subject fail to extract for {'0001437749-23-007261.txt'}
# The subject fail to extract for {'0001437749-23-007531.txt'}
# The subject fail to extract for {'0001437749-23-007537.txt'}
# The subject fail to extract for {'0001437749-23-007710.txt'}
# The subject fail to extract for {'0001437749-23-007858.txt'}
# The subject fail to extract for {'0001437749-23-007951.txt'}
# The subject fail to extract for {'0001437749-23-008107.txt'}
# The subject fail to extract for {'0001437749-23-008189.txt'}
# The subject fail to extract for {'0001437749-23-008226.txt'}
# The subject fail to extract for {'0001437749-23-008658.txt'}
# The subject fail to extract for {'0001437749-23-008793.txt'}
# The subject fail to extract for {'0001437749-23-008795.txt'}
# The subject fail to extract for {'0001437749-23-008847.txt'}
# The subject fail to extract for {'0001472375-22-000055.txt'}
# The subject fail to extract for {'0001477932-22-001902.txt'}
# The subject fail to extract for {'0001477932-22-001921.txt'}
# The subject fail to extract for {'0001477932-22-002206.txt'}
# The subject fail to extract for {'0001477932-22-002230.txt'}
# The subject fail to extract for {'0001477932-22-002284.txt'}
# The subject fail to extract for {'0001477932-22-002301.txt'}
# The subject fail to extract for {'0001477932-22-002322.txt'}
# The subject fail to extract for {'0001477932-22-002405.txt'}
# The subject fail to extract for {'0001477932-22-002409.txt'}
# The subject fail to extract for {'0001477932-22-002481.txt'}
# The subject fail to extract for {'0001477932-22-003594.txt'}
# The subject fail to extract for {'0001477932-22-004007.txt'}
# The subject fail to extract for {'0001477932-22-004392.txt'}
# The subject fail to extract for {'0001477932-22-004928.txt'}
# The subject fail to extract for {'0001477932-22-005146.txt'}
# The subject fail to extract for {'0001477932-22-006967.txt'}
# The subject fail to extract for {'0001477932-22-007238.txt'}
# The subject fail to extract for {'0001477932-22-007292.txt'}
# The subject fail to extract for {'0001477932-22-007297.txt'}
# The subject fail to extract for {'0001477932-22-007358.txt'}
# The subject fail to extract for {'0001477932-23-000738.txt'}
# The subject fail to extract for {'0001477932-23-002029.txt'}
# The subject fail to extract for {'0001477932-23-002090.txt'}
# The subject fail to extract for {'0001477932-23-002112.txt'}
# The subject fail to extract for {'0001477932-23-002123.txt'}
# The subject fail to extract for {'0001493152-22-009403.txt'}
# The subject fail to extract for {'0001493152-22-009475.txt'}
# The subject fail to extract for {'0001493152-22-010064.txt'}
# The subject fail to extract for {'0001493152-22-010132.txt'}
# The subject fail to extract for {'0001493152-23-006881.txt'}
# The subject fail to extract for {'0001493152-23-007879.txt'}
# The subject fail to extract for {'0001493152-23-007933.txt'}
# The subject fail to extract for {'0001493152-23-008010.txt'}
# The subject fail to extract for {'0001493152-23-008240.txt'}
# The subject fail to extract for {'0001493152-23-008441.txt'}
# The subject fail to extract for {'0001493152-23-008554.txt'}
# The subject fail to extract for {'0001493152-23-009386.txt'}
# The subject fail to extract for {'0001493152-23-009492.txt'}
# The subject fail to extract for {'0001493152-23-009519.txt'}

# %% [markdown]
# 3. Part 3:

# %%
rawTextFolderPath = "Corpus Extraction/Part 3/Raw Text/"
rawTextFileName_lst = os.listdir(rawTextFolderPath)
rawTextFilePair_dict = {} # filePair stores the file name and the corresponding file text.
for fileName in rawTextFileName_lst:  
    # encode each document
    filePath = str(rawTextFolderPath) + str(fileName)    
    with open(filePath, 'r', encoding='utf-8') as file:
        rawText = file.read()
    rawTextFilePair_dict[fileName] = rawText

# %%
subjectFormat_lst = ["font-weight:700", "font-weight:bold"]
for key, value in rawTextFilePair_dict.items():
    fileName = key
    rawText = value
    
    i = 0
    subject_lst = []
    
    while not subject_lst:
        subjectFormat = subjectFormat_lst[i]
        subject_lst = extract_subjects(rawText, subjectFormat)
        i += 1
        if i >= len(subjectFormat_lst):
            break
        
    if not subject_lst:
        print("The subject fail to extract for", {fileName})
    else:
        subjectFolder = "Corpus Extraction/Part 3/Subject/"
        subjectFilePath = subjectFolder + str(fileName)
        with open(subjectFilePath, 'w', encoding='utf-8') as file:
            for item in subject_lst:
                file.write(item + '\n')
# Out:
# The subject fail to extract for {'0001493152-23-009742.txt'}
# The subject fail to extract for {'0001493152-23-009765.txt'}
# The subject fail to extract for {'0001493152-23-009907.txt'}
# The subject fail to extract for {'0001493152-23-010013.txt'}
# The subject fail to extract for {'0001493152-23-010120.txt'}
# The subject fail to extract for {'0001493152-23-010129.txt'}
# The subject fail to extract for {'0001493152-23-010160.txt'}
# The subject fail to extract for {'0001493152-23-010166.txt'}
# The subject fail to extract for {'0001493152-23-010210.txt'}
# The subject fail to extract for {'0001493152-23-010345.txt'}
# The subject fail to extract for {'0001510964-22-000033.txt'}
# The subject fail to extract for {'0001510964-23-000016.txt'}
# The subject fail to extract for {'0001513162-23-000040.txt'}
# The subject fail to extract for {'0001515971-22-000125.txt'}
# The subject fail to extract for {'0001520138-22-000237.txt'}
# The subject fail to extract for {'0001552800-23-000003.txt'}
# The subject fail to extract for {'0001553350-22-000344.txt'}
# The subject fail to extract for {'0001553350-22-000730.txt'}
# The subject fail to extract for {'0001553350-23-000218.txt'}
# The subject fail to extract for {'0001553350-23-000241.txt'}
# The subject fail to extract for {'0001554795-22-000246.txt'}
# The subject fail to extract for {'0001558370-23-001217.txt'}
# The subject fail to extract for {'0001558370-23-002357.txt'}
# The subject fail to extract for {'0001558370-23-005103.txt'}
# The subject fail to extract for {'0001558891-22-000031.txt'}
# The subject fail to extract for {'0001558891-23-000023.txt'}
# The subject fail to extract for {'0001558891-23-000025.txt'}
# The subject fail to extract for {'0001562762-23-000048.txt'}
# The subject fail to extract for {'0001562762-23-000132.txt'}
# The subject fail to extract for {'0001564590-22-022408.txt'}
# The subject fail to extract for {'0001575872-23-000353.txt'}
# The subject fail to extract for {'0001599916-22-000104.txt'}
# The subject fail to extract for {'0001599916-22-000148.txt'}
# The subject fail to extract for {'0001599916-22-000205.txt'}
# The subject fail to extract for {'0001599916-22-000224.txt'}
# The subject fail to extract for {'0001607062-22-000284.txt'}
# The subject fail to extract for {'0001640334-22-000807.txt'}
# The subject fail to extract for {'0001640334-22-001335.txt'}
# The subject fail to extract for {'0001640334-22-001338.txt'}
# The subject fail to extract for {'0001640334-22-001381.txt'}
# The subject fail to extract for {'0001640334-22-001390.txt'}
# The subject fail to extract for {'0001640334-22-001613.txt'}
# The subject fail to extract for {'0001640334-22-001828.txt'}
# The subject fail to extract for {'0001640334-22-002071.txt'}
# The subject fail to extract for {'0001640334-23-000372.txt'}
# The subject fail to extract for {'0001640334-23-000444.txt'}
# The subject fail to extract for {'0001640334-23-000500.txt'}
# The subject fail to extract for {'0001640334-23-000509.txt'}
# The subject fail to extract for {'0001654954-22-004427.txt'}
# The subject fail to extract for {'0001654954-22-005014.txt'}
# The subject fail to extract for {'0001654954-22-005270.txt'}
# The subject fail to extract for {'0001654954-22-011877.txt'}
# The subject fail to extract for {'0001654954-22-012824.txt'}
# The subject fail to extract for {'0001654954-22-012862.txt'}
# The subject fail to extract for {'0001654954-23-001926.txt'}
# The subject fail to extract for {'0001654954-23-002127.txt'}
# The subject fail to extract for {'0001654954-23-002437.txt'}
# The subject fail to extract for {'0001654954-23-002845.txt'}
# The subject fail to extract for {'0001654954-23-003057.txt'}
# The subject fail to extract for {'0001654954-23-003260.txt'}
# The subject fail to extract for {'0001654954-23-003759.txt'}
# The subject fail to extract for {'0001654954-23-003841.txt'}
# The subject fail to extract for {'0001654954-23-003905.txt'}
# The subject fail to extract for {'0001654954-23-004087.txt'}
# The subject fail to extract for {'0001654954-23-004101.txt'}
# The subject fail to extract for {'0001654954-23-004106.txt'}
# The subject fail to extract for {'0001674796-23-000007.txt'}
# The subject fail to extract for {'0001683168-22-002295.txt'}
# The subject fail to extract for {'0001683168-22-002648.txt'}
# The subject fail to extract for {'0001683168-22-004641.txt'}
# The subject fail to extract for {'0001683168-22-005189.txt'}
# The subject fail to extract for {'0001683168-23-001237.txt'}
# The subject fail to extract for {'0001683168-23-001513.txt'}
# The subject fail to extract for {'0001683168-23-001661.txt'}
# The subject fail to extract for {'0001683168-23-001729.txt'}
# The subject fail to extract for {'0001683168-23-001882.txt'}
# The subject fail to extract for {'0001683168-23-001957.txt'}
# The subject fail to extract for {'0001731122-22-000776.txt'}
# The subject fail to extract for {'0001731122-22-001152.txt'}
# The subject fail to extract for {'0001731122-23-000260.txt'}
# The subject fail to extract for {'0001731122-23-000448.txt'}
# The subject fail to extract for {'0001731122-23-000536.txt'}
# The subject fail to extract for {'0001740797-22-000007.txt'}
# The subject fail to extract for {'0001753373-23-000006.txt'}
# The subject fail to extract for {'0001756497-22-000007.txt'}
# The subject fail to extract for {'0001758699-23-000004.txt'}
# The subject fail to extract for {'0001765048-23-000003.txt'}
# The subject fail to extract for {'0001829126-22-007958.txt'}
# The subject fail to extract for {'0001848672-22-000008.txt'}
# The subject fail to extract for {'0001903596-23-000201.txt'}
# The subject fail to extract for {'0001929980-23-000010.txt'}

# %% [markdown]
# ## 4.1.4 Organizing and Cleansing
# We are going to re-organize and cleanse these 3 parts of corpus into a entire file.
#
# ### 1. Organizing the .txt Files in .csv Files
#
# 1. Part 1:

# %%
def generate_subject_form(folderPath, outputPath):
    adsh_lst = []
    
    fileName_lst = os.listdir(folderPath)
    riskFactorSubject_lst = []
    for fileName in fileName_lst:
        adsh = fileName.rstrip(".txt")
        filePath = str(folderPath) + str(fileName)    
        with open(filePath, 'r', encoding='utf-8') as file:
            fileText = file.read()
    
        subject = fileText.split('\n')
        riskFactorSubject_lst.extend(subject)
        adsh_lst.extend([adsh] * len(subject))
    df = pd.DataFrame(list(zip(adsh_lst, riskFactorSubject_lst)), columns=['adsh', 'Risk Factors'])
    df.to_csv(outputPath, index=False)
    return df

# %%
CorpusFolderPath1 = "Corpus Extraction/Part 1/Subject/"
CorpusOutputPath1 = "Corpus Extraction/Part 1/Corpus1.csv"
Corpus_df1 = generate_subject_form(CorpusFolderPath1, CorpusOutputPath1)
Corpus_df1.head()
# Out:
#                    adsh                                       Risk Factors
# 0  0000004904-23-000011              GENERAL RISKS OF REGULATED OPERATIONS
# 1  0000004904-23-000011  AEP may not be able to recover the costs of su...
# 2  0000004904-23-000011  Regulated electric revenues and earnings are d...
# 3  0000004904-23-000011  AEP’s transmission investment strategy and exe...
# 4  0000004904-23-000011  Certain elements of AEP’s transmission formula...

# %% [markdown]
# 2. Part 2:

# %%
CorpusFolderPath2 = "Corpus Extraction/Part 2/Subject/"
CorpusOutputPath2 = "Corpus Extraction/Part 2/Corpus2.csv"
Corpus_df2 = generate_subject_form(CorpusFolderPath2, CorpusOutputPath2)
Corpus_df2.head()
# Out:
#                    adsh                                       Risk Factors
# 0  0001193125-23-044850                                                Age
# 1  0001193125-23-044850  Young-Joon (YJ) Kim, Board of Directors, Membe...
# 2  0001193125-23-044850           Shin Young Park, Chief Financial Officer
# 3  0001193125-23-044850                                                 .
# 4  0001193125-23-044850  Theodore Kim, Chief Compliance Officer, Genera...

# %% [markdown]
# 3. Part 3:

# %%
CorpusFolderPath3 = "Corpus Extraction/Part 3/Subject/"
CorpusOutputPath3 = "Corpus Extraction/Part 3/Corpus3.csv"
Corpus_df3 = generate_subject_form(CorpusFolderPath3, CorpusOutputPath3)
Corpus_df3.head()
# Out:
#                    adsh                                       Risk Factors
# 0  0001495320-22-000007             Risks Related to the COVID-19 Pandemic
# 1  0001495320-22-000007  The outbreak of the novel coronavirus (COVID-1...
# 2  0001495320-22-000007  Risks Related to Our Business Operations and I...
# 3  0001495320-22-000007  If we are unable to successfully implement our...
# 4  0001495320-22-000007                                  Table of Contents

# %% [markdown]
# ### 2. Combination

# %%
Corpus_df = pd.concat([Corpus_df1, Corpus_df2, Corpus_df3], axis=0)
print("The first 5 records are shown below: \n", Corpus_df.head(), "\n")
print("There are ", len(Corpus_df), "records in the corpus.")
# Out:
# The first 5 records are shown below:
#                     adsh                                       Risk Factors
# 0  0000004904-23-000011              GENERAL RISKS OF REGULATED OPERATIONS
# 1  0000004904-23-000011  AEP may not be able to recover the costs of su...
# 2  0000004904-23-000011  Regulated electric revenues and earnings are d...
# 3  0000004904-23-000011  AEP’s transmission investment strategy and exe...
# 4  0000004904-23-000011  Certain elements of AEP’s transmission formula...
#
# There are  135436 records in the corpus.

# %% [markdown]
# ### 3. Cleansing
# There are some empty line and incompleted line in the documents so we need to remove them.

# %%
import string
Corpus_df = Corpus_df.dropna()
Corpus_df = Corpus_df[Corpus_df["Risk Factors"].str.match(r'^[a-zA-Z,.\s\'"?!]+$')]
Corpus_df = Corpus_df[~Corpus_df["Risk Factors"].str.startswith(" ")]
punctuations = string.punctuation
for p in punctuations:
    Corpus_df = Corpus_df[~Corpus_df["Risk Factors"].str.startswith(p)]
Corpus_df = Corpus_df[Corpus_df['Risk Factors'].str.split().str.len() > 2]
print("There are ", len(Corpus_df), "records in the corpus.")
# Out:
# There are  55898 records in the corpus.

# %% [markdown]
# The subjects we extract in section 2 can also used to build up the corpus, so we combine them together.

# %%
folderPath = "../Section 2 - Risk Factor Extraction/Risk Factor Text/Risk Factor Subject Text Summary/"
fileName_lst = os.listdir(folderPath)
df_lst = []
for fileName in fileName_lst:
    filePath = str(folderPath) + str(fileName)
    df_lst.append(pd.read_csv(filePath))
riskCorpus_df = pd.concat(df_lst, axis=0)
print("The first 5 records in the corpus are shown below: \n", riskCorpus_df.head(), "\n")
print("There are", len(riskCorpus_df), "records in the corpus.")
# Out:
# The first 5 records in the corpus are shown below:
#                     adsh                                       Risk Factors
# 0  0000007332-23-000005  Natural gas, oil and NGL prices and basis diff...
# 1  0000007332-23-000005  Significant capital investment is required to ...
# 2  0000007332-23-000005  If we are not able to develop and replace rese...
# 3  0000007332-23-000005  Our business depends on access to natural gas,...
# 4  0000007332-23-000005  Strategic determinations, including the alloca...
#
# There are 33103 records in the corpus.

# %%
Corpus_df = pd.concat([Corpus_df, riskCorpus_df], axis=0)

# %% [markdown]
# ### 4. Output the file

# %%
Corpus_df.to_csv("Corpus.csv", index=False)
